# %%
# !pip install opencv-python
# !pip install mediapipe
# !pip install pyautogui
# Out:
# Requirement already satisfied: opencv-python in c:\users\dell\anaconda3\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\dell\anaconda3\lib\site-packages (from opencv-python) (1.23.5)
# Requirement already satisfied: mediapipe in c:\users\dell\anaconda3\lib\site-packages (0.10.10)
# Requirement already satisfied: jax in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (0.4.8)
# Requirement already satisfied: matplotlib in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (3.5.2)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (23.3.3)
# Requirement already satisfied: opencv-contrib-python in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (4.9.0.80)
# Requirement already satisfied: absl-py in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (21.4.0)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (1.23.5)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\dell\anaconda3\lib\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: CFFI>=1.0 in c:\users\dell\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: scipy>=1.7 in c:\users\dell\anaconda3\lib\site-packages (from jax->mediapipe) (1.9.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in c:\users\dell\anaconda3\lib\site-packages (from jax->mediapipe) (0.1.0)
# Requirement already satisfied: opt-einsum in c:\users\dell\anaconda3\lib\site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mediapipe) (10.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mediapipe) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in c:\users\dell\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Requirement already satisfied: pyautogui in c:\users\dell\anaconda3\lib\site-packages (0.9.54)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\dell\anaconda3\lib\site-packages (from pyautogui) (0.1.30)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\dell\anaconda3\lib\site-packages (from pyautogui) (1.2.0)
# Requirement already satisfied: mouseinfo in c:\users\dell\anaconda3\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pymsgbox in c:\users\dell\anaconda3\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\dell\anaconda3\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: pyrect in c:\users\dell\anaconda3\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: Pillow>=9.2.0 in c:\users\dell\anaconda3\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (10.2.0)
# Requirement already satisfied: pyperclip in c:\users\dell\anaconda3\lib\site-packages (from mouseinfo->pyautogui) (1.8.2)

# %%
import cv2
import mediapipe as mp
import pyautogui
cap = cv2.VideoCapture(0)  # Use 0 for the default webcam
hand_detector = mp.solutions.hands.Hands()
drawing_utils = mp.solutions.drawing_utils
screen_width, screen_height = pyautogui.size()
index_y = 0

# %%
while True:
    _, frame = cap.read()
    frame = cv2.flip(frame, 1)
    frame_height, frame_width, _ = frame.shape
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    output = hand_detector.process(rgb_frame)
    hands = output.multi_hand_landmarks
    if hands:
        for hand in hands:
            drawing_utils.draw_landmarks(frame, hand)
            landmarks = hand.landmark
            for id, landmark in enumerate(landmarks):
                x = int(landmark.x*frame_width)
                y = int(landmark.y*frame_height)
                if id == 8:
                    cv2.circle(img=frame, center=(x,y), radius=10, color=(0, 255, 255))
                    index_x = screen_width/frame_width*x
                    index_y = screen_height/frame_height*y
                    pyautogui.moveTo(index_x,index_y)
                if id == 4:
                    cv2.circle(img=frame, center=(x,y), radius=10, color=(0, 255, 255))
                    thumb_x = screen_width/frame_width*x
                    thumb_y = screen_height/frame_height*y
                    print('outside', abs(index_y - thumb_y))
                    if abs(index_y - thumb_y) < 20:
                        pyautogui.click()
                        pyautogui.sleep(1)
                    elif abs(index_y - thumb_y) < 100:
                        pyautogui.moveTo(index_x, index_y)
    cv2.imshow('Virtual Mouse', frame)
    cv2.waitKey(1)
# Out:
# outside 303.75
# outside 186.75
# outside 49.5
# outside 2.25
# outside 94.5
# outside 308.25
# outside 283.5
# outside 69.75
# outside 108.0
# outside 110.25
# outside 117.0
# outside 204.75
# outside 193.5
# outside 29.25
# outside 238.5
# outside 168.75
# outside 36.0
# outside 310.5
# outside 153.0
# outside 51.75
# outside 76.5
# outside 27.0
# outside 101.25
# outside 90.0
# outside 18.0
# outside 49.5
# outside 33.75
# outside 60.75
# outside 29.25
# outside 63.0
# outside 454.5
# outside 207.0
# outside 6.75
# outside 528.75
# outside 220.5
# outside 180.0
# outside 146.25
# outside 123.75
# outside 92.25
# outside 42.75
# outside 42.75
# outside 11.25
# outside 227.25
# outside 297.0
# outside 213.75
# outside 306.0
# outside 108.0
# outside 240.75
# outside 36.0
# outside 51.75
# outside 65.25
# outside 72.0
# outside 96.75
# outside 123.75
# outside 141.75
# outside 139.5
# outside 175.5
# outside 155.25
# outside 173.25
# outside 141.75
# outside 157.5
# outside 164.25
# outside 105.75
# outside 94.5
# outside 85.5
# outside 333.0
# outside 256.5
# outside 285.75
# outside 288.0
# outside 274.5
# outside 263.25
# outside 303.75
# outside 351.0
# outside 328.5
# outside 324.0
# outside 274.5
# outside 69.75
# outside 245.25
# outside 211.5
# outside 234.0
# outside 0.0
# outside 117.0
# outside 204.75
# outside 231.75
# outside 222.75
# outside 225.0
# outside 227.25
# outside 218.25
# outside 200.25
# outside 434.25
# outside 564.75
# outside 330.75
# outside 447.75
# outside 276.75
# outside 114.75
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18136\2511066876.py in <module>
#       1 while True:
# ----> 2     _, frame = cap.read()
#       3     frame = cv2.flip(frame, 1)
#       4     frame_height, frame_width, _ = frame.shape
#       5     rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#
# KeyboardInterrupt:
